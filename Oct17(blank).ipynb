# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas is a **library** containing functions, methods, and data types that allow us to analyze data. To use the functions contained in pandas, we must first **import** the module. The ``as pd`` part tells the computer that whenever we want to use a function from pandas, we can refer to it using ``pd``.

# %%
# Make sure to run this first!!
import pandas as pd

# %% [markdown]
# (Tip: make your own list of common pieces of code and syntax so you can easily refer to it, like a cheat sheet.)
#
# https://melaniewalsh.github.io/Intro-Cultural-Analytics/03-Data-Analysis/01-Pandas-Basics-Part1.html
#
# https://www.w3schools.com/python/pandas/pandas_ref_dataframe.asp

# %% [markdown]
# ## Data types in pandas
# | Python         | Pandas             |
# |----------------|--------------------|
# |String (`str`)  | Object (`object`)  |
# |Integer (`int`) | Int64 (`int64`)    |
# |Float (`float`) | Float64 (`float64`)|
# |List (`list`)   |$\approx$ Series (`Series`)   |
# |                |DataFrames (`DataFrame`)|

# %% [markdown]
# ## Creating a variable for a file as a dataframe

# %% [markdown]
# ### Question 1
#
# For this tutorial demo, we will use data published by the Seattle Public Library concerning items that were checked out in April 2020. To use the file ``seattle_checkouts.csv``, you can upload this notebook directly to your Week 7 Lab folder. Note this is a csv file, so we **do not need** the parameter ``sep="\t"`` when using ``read_csv``.
#
# The two pieces of code below each have an error. Run the code, identify the two errors, then correct it.

# %%
checkouts_df = read_csv('seattle_checkouts.csv')

# %%
checkouts_df = pd.read_csv('seattle_checkouts.tsv')

# %%
# Write the correct line here, then run it:

# %% [markdown]
# ## Selecting Columns

# %% [markdown]
# Note: using ``print(checkouts_df)`` does not produce a nice readable output for a dataframe. Instead, you can just type the variable name and run the cell to view the dataframe.

# %%
#Run this cell to see the dataframe stored in checkouts_df.
checkouts_df

# %% [markdown]
# ### Question 2
# I want to isolate the columns containing the number of checkouts, title, and creator of each work, then store the resulting dataframe in a new variable. Identify the error, then correct it.

# %%
trimmed_checkouts_df = checkouts_df[["checkouts", "title", "creator"]]

# %% [markdown]
# ## Counting values in a dataframe

# %% [markdown]
# ### Question 3
# In lecture, we used the line
#
# ``nyt_df['title'].value_counts()``
#
# to find the most common titles among the entries in the dataframe ``nyt_df``.
#
# **3a)** Modify the line to find the most common publication years among the items in ``checkouts_df``.

# %%
nyt_df['title'].value_counts()

# %% [markdown]
# **3b)** Create a bar graph displaying the most common publication years among the items in ``checkouts_df``.

# %%
# Modify this line of code to get what you want:
nyt_df['author'].value_counts()[:10].plot(
    kind='pie', figsize=(10, 10), title='NYT Best Sellers:\nTen Authors Who Appear Most Frequently'
)

# %% [markdown]
# ## Filtering data

# %% [markdown]
# ### Question 4
#
# In lecture we used the code
#
# ``nyt_df[nyt_df['author'] == 'Toni Morrison']``
#
# to create a new dataframe containing only the entries in ``nyt_df`` written by Toni Morrison, i.e. the entries whose ``author`` value is ``'Toni Morrison'``.
#
# **4a)** Modify the line to get a dataframe containing only the works in ``checkouts_df`` written by Geronimo Stilton and store the result in a variable called `stilton_df`.

# %%
nyt_df[nyt_df['author'] == 'Toni Morrison']

# %% [markdown]
# **4b)** Similarly, get a dataframe containing only the works in ``checkouts_df`` that are audiobooks and store the result in a variable called ``audiobooks_df``.

# %% [markdown]
# ## Using `.describe()`

# %% [markdown]
# ### Question 5
#
# **5a)** Write down what each of the rows in the table means.
#
# - count:
# - unique:
# - top:
# - mean:
# - std:
# - min:
# - 25%:
# - 50%:
# - 75%:
# - max:
#
# **5b)** Some of the entries say ``NaN``, which means "Not a number". What do you think is the reason for this?

# %%
checkouts_df.describe(include="all")
# Out:
#        UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# count       93671        93671        93671       93671.0        93671.0
# unique          2            2            8           NaN            NaN
# top       Digital    OverDrive        EBOOK           NaN            NaN
# freq        93594        93594        67548           NaN            NaN
# mean          NaN          NaN          NaN        2020.0            4.0
# std           NaN          NaN          NaN           0.0            0.0
# min           NaN          NaN          NaN        2020.0            4.0
# 25%           NaN          NaN          NaN        2020.0            4.0
# 50%           NaN          NaN          NaN        2020.0            4.0
# 75%           NaN          NaN          NaN        2020.0            4.0
# max           NaN          NaN          NaN        2020.0            4.0
#
#            Checkouts            Title          Creator             Subjects  \
# count   93671.000000            93671            93639                93669
# unique           NaN            92371            29618                 4413
# top              NaN  Treasure Island  James Patterson  Fiction, Literature
# freq             NaN                7              370                 4863
# mean        3.785291              NaN              NaN                  NaN
# std        11.711254              NaN              NaN                  NaN
# min         1.000000              NaN              NaN                  NaN
# 25%         1.000000              NaN              NaN                  NaN
# 50%         2.000000              NaN              NaN                  NaN
# 75%         4.000000              NaN              NaN                  NaN
# max      1894.000000              NaN              NaN                  NaN
#
#                  Publisher PublicationYear
# count                93671           93668
# unique                 522              36
# top     Random House, Inc.            2013
# freq                 13631           10442
# mean                   NaN             NaN
# std                    NaN             NaN
# min                    NaN             NaN
# 25%                    NaN             NaN
# 50%                    NaN             NaN
# 75%                    NaN             NaN
# max                    NaN             NaN

# %% [markdown]
# **5b)** Explain how the output of ``.describe()`` differs when using different parameters.

# %%
checkouts_df[:5]
# Out:
#   UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 0    Digital    OverDrive        EBOOK          2020              4
# 1    Digital    OverDrive        EBOOK          2020              4
# 2    Digital    OverDrive    AUDIOBOOK          2020              4
# 3    Digital    OverDrive        EBOOK          2020              4
# 4    Digital    OverDrive        EBOOK          2020              4
#
#    Checkouts                    Title            Creator  \
# 0          2       Nighttime Symphony          Timbaland
# 1          2                Cold Kill       Rennie Airth
# 2          1  The Choice (Unabridged)    Nicholas Sparks
# 3          3    The Master Key System  Charles F. Haanel
# 4         12        The Doughnut King    Jessie Janowitz
#
#                                  Subjects                    Publisher  \
# 0  Juvenile Fiction, Picture Book Fiction       Simon & Schuster, Inc.
# 1              Fiction, Mystery, Thriller  Severn House Publishers Ltd
# 2                     Fiction, Literature                Books on Tape
# 3   New Age, Nonfiction, Self-Improvement                Duke Classics
# 4   Juvenile Fiction, Juvenile Literature                  Sourcebooks
#
#   PublicationYear
# 0            2019
# 1            2020
# 2            2007
# 3            2020
# 4            2019

# %%
checkouts_df.describe(include="object")
# Out:
#        UsageClass CheckoutType MaterialType            Title          Creator  \
# count       93671        93671        93671            93671            93639
# unique          2            2            8            92371            29618
# top       Digital    OverDrive        EBOOK  Treasure Island  James Patterson
# freq        93594        93594        67548                7              370
#
#                    Subjects           Publisher PublicationYear
# count                 93669               93671           93668
# unique                 4413                 522              36
# top     Fiction, Literature  Random House, Inc.            2013
# freq                   4863               13631           10442

# %%
checkouts_df.describe(include="int64")
# Out:
#        CheckoutYear  CheckoutMonth     Checkouts
# count       93671.0        93671.0  93671.000000
# mean         2020.0            4.0      3.785291
# std             0.0            0.0     11.711254
# min          2020.0            4.0      1.000000
# 25%          2020.0            4.0      1.000000
# 50%          2020.0            4.0      2.000000
# 75%          2020.0            4.0      4.000000
# max          2020.0            4.0   1894.000000

# %%
# Observe what happens if I try this:

checkouts_df.describe(include="Creator")

# I get an error because the parameter must be a data type; I can't use a column name, for example.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Observe what happens if I try this:
# ----> 3 checkouts_df.describe(include="Creator")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:11544, in NDFrame.describe(self, percentiles, include, exclude)
#   11302 @final
#   11303 def describe(
#   11304     self,
#    (...)
#   11307     exclude=None,
#   11308 ) -> Self:
#   11309     """
#   11310     Generate descriptive statistics.
#   11311
#    (...)
#   11542     max            NaN      3.0
#   11543     """
# > 11544     return describe_ndframe(
#   11545         obj=self,
#   11546         include=include,
#   11547         exclude=exclude,
#   11548         percentiles=percentiles,
#   11549     ).__finalize__(self, method="describe")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/methods/describe.py:97, in describe_ndframe(obj, include, exclude, percentiles)
#      90 else:
#      91     describer = DataFrameDescriber(
#      92         obj=cast("DataFrame", obj),
#      93         include=include,
#      94         exclude=exclude,
#      95     )
# ---> 97 result = describer.describe(percentiles=percentiles)
#      98 return cast(NDFrameT, result)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/methods/describe.py:165, in DataFrameDescriber.describe(self, percentiles)
#     164 def describe(self, percentiles: Sequence[float] | np.ndarray) -> DataFrame:
# --> 165     data = self._select_data()
#     167     ldesc: list[Series] = []
#     168     for _, series in data.items():
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/methods/describe.py:195, in DataFrameDescriber._select_data(self)
#     193     data = self.obj
#     194 else:
# --> 195     data = self.obj.select_dtypes(
#     196         include=self.include,
#     197         exclude=self.exclude,
#     198     )
#     199 return data
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:4836, in DataFrame.select_dtypes(self, include, exclude)
#    4833             converted_dtypes.append(infer_dtype_from_object(dtype))
#    4834     return frozenset(converted_dtypes)
# -> 4836 include = check_int_infer_dtype(include)
#    4837 exclude = check_int_infer_dtype(exclude)
#    4839 for dtypes in (include, exclude):
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:4833, in DataFrame.select_dtypes.<locals>.check_int_infer_dtype(dtypes)
#    4831         converted_dtypes.extend([np.float64, np.float32])
#    4832     else:
# -> 4833         converted_dtypes.append(infer_dtype_from_object(dtype))
#    4834 return frozenset(converted_dtypes)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/dtypes/common.py:1533, in infer_dtype_from_object(dtype)
#    1524     except (AttributeError, TypeError):
#    1525         # Handles cases like _get_dtype(int) i.e.,
#    1526         # Python objects that are valid dtypes
#    (...)
#    1529         # TypeError handles the float16 type code of 'e'
#    1530         # further handle internal types
#    1531         pass
# -> 1533 return infer_dtype_from_object(np.dtype(dtype))
#
# TypeError: data type 'Creator' not understood

# %% [markdown]
# # Lab 7 Review

# %% [markdown]
# **Question 6**
#
# **6a)** What is the difference between the following two lines of code?

# %%
checkouts_df['Title'].value_counts()[:10]
# Out:
# Title
# Treasure Island                                              7
# Black Beauty                                                 6
# The Time Machine                                             6
# Jane Eyre                                                    6
# Frankenstein                                                 6
# Dracula                                                      6
# The Road Home                                                5
# Madame Bovary                                                5
# Pride and Prejudice                                          5
# Anne of Green Gables: Anne of Green Gables Series, Book 1    5
# Name: count, dtype: int64

# %%
checkouts_df.nlargest(10, 'Checkouts')
# Out:
#       UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 46348    Digital    OverDrive    AUDIOBOOK          2020              4
# 78951    Digital    OverDrive        EBOOK          2020              4
# 86961    Digital    OverDrive        EBOOK          2020              4
# 30319    Digital    OverDrive        EBOOK          2020              4
# 30025    Digital    OverDrive    AUDIOBOOK          2020              4
# 76066    Digital    OverDrive        EBOOK          2020              4
# 59372    Digital    OverDrive        EBOOK          2020              4
# 33571    Digital    OverDrive    AUDIOBOOK          2020              4
# 39473    Digital    OverDrive        EBOOK          2020              4
# 81117    Digital    OverDrive    AUDIOBOOK          2020              4
#
#        Checkouts                                              Title  \
# 46348       1894  Harry Potter and the Sorcerer's Stone: Harry P...
# 78951        743  Harry Potter and the Sorcerer's Stone: Harry P...
# 86961        565                                           Becoming
# 30319        553  Funny, You Don't Look Autistic: A Comedian's G...
# 30025        520                              Becoming (Unabridged)
# 76066        478                                 Educated: A Memoir
# 59372        462                            Where the Crawdads Sing
# 33571        433           Everything I Never Told You (Unabridged)
# 39473        409  Crazy Rich Asians: Crazy Rich Asians Series, B...
# 81117        354  Talking to Strangers: What We Should Know abou...
#
#                 Creator                                           Subjects  \
# 46348     J. K. Rowling              Juvenile Fiction, Juvenile Literature
# 78951     J. K. Rowling              Juvenile Fiction, Juvenile Literature
# 86961    Michelle Obama  African American Nonfiction, Biography & Autob...
# 30319  Michael McCreary  Biography & Autobiography, Performing Arts, So...
# 30025    Michelle Obama  African American Nonfiction, Biography & Autob...
# 76066     Tara Westover  Biography & Autobiography, Nonfiction, Religio...
# 59372       Delia Owens                                Fiction, Literature
# 33571        Celeste Ng                                Fiction, Literature
# 39473        Kevin Kwan      Fiction, Humor (Fiction), Literature, Romance
# 81117  Malcolm Gladwell                  Nonfiction, Psychology, Sociology
#
#                        Publisher PublicationYear
# 46348                 Pottermore            2012
# 78951                 Pottermore            2012
# 86961         Random House, Inc.            2018
# 30319               Annick Press             NaN
# 30025              Books on Tape            2018
# 76066         Random House, Inc.            2018
# 59372  Penguin Group (USA), Inc.            2018
# 33571     Blackstone Audio, Inc.            2014
# 39473         Random House, Inc.            2013
# 81117     Blackstone Audio, Inc.            2019

# %% [markdown]
# **6b)** Why do you think the most checked-out books do not coincide with the most frequently listed writers? Do you think we can conclude that J.K. Rowling is the author whose works were checked out the most in this time period?

# %%
checkouts_df['Creator'].value_counts()[:20]
# Out:
# Creator
# James Patterson              370
# Daisy Meadows                219
# Agatha Christie              211
# Gertrude  Chandler Warner    174
# Geronimo Stilton             172
# Mary Pope Osborne            170
# Stephen King                 168
# Louis L'Amour                167
# Nora Roberts                 158
# Erin Hunter                  152
# Dan Gutman                   147
# M. C. Beaton                 144
# Stuart Woods                 144
# Stan Berenstain              136
# DK                           131
# Robert B. Parker             120
# Janet Evanovich              116
# Clive Cussler                116
# J. A. Jance                  112
# Debbie Macomber              111
# Name: count, dtype: int64
